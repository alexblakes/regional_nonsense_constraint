# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Imports
import matplotlib.pyplot as plt
import pandas as pd

from src import constants as C
from src import visualisation as vis
from src.visualisation import maps_plots

# %%
# Style and palette
plt.style.use(C.STYLE_DEFAULT)
palette = vis.color_palette("maps")

# %%
# Read the data
maps = pd.read_csv(C.STATS_MAPS, sep="\t")

# %%
# MAPS plot
for i, row in maps.iterrows():
    maps_plots.plot_maps(y=row["csq"], x=row["maps"], xerr=row["ci95"], color=palette[i])
