# %% [markdown]
# # Z vs LOEUF plot

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Imports
import matplotlib.pyplot as plt
import pandas as pd

from src import constants as C
from src import visualisation as vis
from src.visualisation import z_loeuf_plots

# %%
# Style and palette
plt.style.use(C.STYLE_DEFAULT)
palette = vis.color_palette("regions")

# %%
# Load data
z_loeuf = pd.read_csv(C.STATS_Z_LOEUF, sep="\t")

# %%
# Plots
z_loeuf_plots.hexbin(z_loeuf, cmap="Blues",zmin=-7.5, zmax=2.5)
z_loeuf_plots.axis_labels()
z_loeuf_plots.add_rho(0.88)
