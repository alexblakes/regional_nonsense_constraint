# %% [markdown]
# # Get PanelApp genes
# Download rare disease genes using PanelApp API

# %%
import requests
import json
import pandas as pd

# %%
p = {
    "entity_name":"ABL1",
}
r = requests.get("https://panelapp.genomicsengland.co.uk/api/v1/genes/", params=p)

# %%
r.url
# Out:
# 'https://panelapp.genomicsengland.co.uk/api/v1/genes/?entity_name=ABL1'

# %%
j = r.json()

# %%
j1 = json.dumps(r.json(), indent=4, sort_keys=True)

# %%
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# %%
jprint(j)
# Out:
# {
#     "count": 11,
#     "next": null,
#     "previous": null,
#     "results": [
#         {
#             "confidence_level": "2",
#             "entity_name": "ABL1",
#             "entity_type": "gene",
#             "evidence": [
#                 "Expert Review Amber",
#                 "Literature"
#             ],
#             "gene_data": {
#                 "alias": [
#                     "JTK7",
#                     "c-ABL",
#                     "p150"
#                 ],
#                 "alias_name": null,
#                 "biotype": "protein_coding",
#                 "ensembl_genes": {
#                     "GRch37": {
#                         "82": {
#                             "ensembl_id": "ENSG00000097007",
#                             "location": "9:133589333-133763062"
#                         }
#                     },
#                     "GRch38": {
#                         "90": {
#                             "ensembl_id": "ENSG00000097007",
# ...

# %%
response = requests.get("https://panelapp.genomicsengland.co.uk/api/v1/genes/?format=json", params=parameters)

# %%
type(response.json()["results"])
# Out:
# list

# %%
df = pd.DataFrame.from_dict(response.json())
