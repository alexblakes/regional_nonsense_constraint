# %%
import numpy as np
import pandas as pd

# %run _color_tools.ipynb
# Out:
# The color palette is saved in the global variable, C
# C = color_palette(blue='#0077bb', green='#009988', orange='#ee7733', red='#cc3311', light_blue='#33bbee', pink='#ee3377', grey='#bbbbbb', black='#000000')

# %%
# %%capture
# No output

# %run fig_s1_region_footprint.ipynb
# %run fig_s1_region_sizes.ipynb

# %%
cm = 1 / 2.54

# %%
fig = plt.figure(figsize=(18 * cm, 12 * cm), layout="constrained")
subfigs = fig.subfigures(1, 3, width_ratios=(1.25, 1.25, 1))
subsubfigs = subfigs[2].subfigures(2, 1, height_ratios=(4, 1))

axs_left = subfigs[0].subplots(5, 1, sharex=True)
axs_center = subfigs[1].subplots(5, 1, sharex=True)
ax_right = subsubfigs[0].subplots(1, 1)

plot_region_footprint(region_count, axs_left[0], "n", "transcript")
plot_region_footprint(region_count, axs_left[1], "n", "nmd_target")
plot_region_footprint(region_count, axs_left[2], "n", "long_exon")
plot_region_footprint(region_count, axs_left[3], "n", "distal_nmd")
plot_region_footprint(
    region_count,
    axs_left[4],
    "n",
    "start_proximal",
    xlabel="Count",
)

plot_region_footprint(region_footprint, axs_center[0], "size", "transcript", yticklabels=False)
plot_region_footprint(region_footprint, axs_center[1], "size", "nmd_target", yticklabels=False)
plot_region_footprint(region_footprint, axs_center[2], "size", "long_exon", yticklabels=False)
plot_region_footprint(region_footprint, axs_center[3], "size", "distal_nmd", yticklabels=False)
plot_region_footprint(
    region_footprint,
    axs_center[4],
    "size",
    "start_proximal",
    xlabel="Genomic Footprint (nt)",
    legend=True,
    legend_x_shift=1.3,
    yticklabels=False
)


plot_region_sizes(region_sizes, ax_right, yticklabels=False, legend=False)
